# %% [markdown]
# ### Objective

# %% [raw]
# Learn how to connect to social media network (we will use Twitter as example in this assignment), and collect/preprocess/analyze its data
#
#
# Tweets Data Can be used for different purposes by marketing department and data analytics team. For example:
#
# - Compete with rivals to offer price-match gaurantee policy
# - Offer same coupons like rivals in the market place

# %% [markdown]
# ### Installation and Setup

# %% [raw]
# For this assignment you need to do the following setup first:
#
# 1.  Create an account on twitter.com.
#
# 2.  Generate authentication tokens by following the instructions here :
#     https://dev.twitter.com/oauth/overview/application-owner-access-tokens
#
# 3.  Add your tokens to the credentials.txt file.

# %% [markdown]
# ### Twitter API

# %% [raw]
# Twitter API
#
# Two APIs:
#
#     REST API: Submit HTTP requests to access specific information (tweets, friends, ...)
#     Streaming API: Open a continuous connection to Twitter to receive real-time data.
#
# These APIs are  HTTP GET request
#
#
#
#
# Here are the twitter API docs that you must familiarize yourself with
#
# https://dev.twitter.com/rest/reference/get/followers/ids
#
# https://dev.twitter.com/overview/api/twitter-libraries

# %% [raw]
# When you search in a text (tweets are text messages), often you need to be aware of something STOP WORDS.
# You could read more about stop-words here:
#
#     https://en.wikipedia.org/wiki/Stop_words

# %% [markdown]
# # Lets create twitter object and use its API. Code snippets below will show you how to use this API

# %%
from TwitterAPI import TwitterAPI, TwitterOAuth, TwitterPager

# %%
o = TwitterOAuth.read_file('C:/apache-tomcat-7.0.34/webapps/KNNHealthCare/credentials.txt')

# %%
o.access_token_key
# Out:
# '1059663986684239875-6EWCj8s3uoPrN6wFimhCScqSZ7EhaN'

# %%
# Using OAuth1...
twitter = TwitterAPI(o.consumer_key,
                 o.consumer_secret,
                 o.access_token_key,
                 o.access_token_secret)

# %%
help(twitter)
# Out:
# Help on TwitterAPI in module TwitterAPI.TwitterAPI object:
#
# class TwitterAPI(builtins.object)
#  |  TwitterAPI(consumer_key=None, consumer_secret=None, access_token_key=None, access_token_secret=None, auth_type='oAuth1', proxy_url=None)
#  |
#  |  Access REST API or Streaming API resources.
#  |
#  |  :param consumer_key: Twitter application consumer key
#  |  :param consumer_secret: Twitter application consumer secret
#  |  :param access_token_key: Twitter application access token key
#  |  :param access_token_secret: Twitter application access token secret
#  |  :param auth_type: "oAuth1" (default) or "oAuth2"
#  |  :param proxy_url: HTTPS proxy URL string (ex. "https://USER:PASSWORD@SERVER:PORT"),
#  |                    or dict of URLs (ex. {'http':'http://SERVER', 'https':'https://SERVER'})
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, consumer_key=None, consumer_secret=None, access_token_key=None, access_token_secret=None, auth_type='oAuth1', proxy_url=None)
#  |      Initialize with your Twitter application credentials
#  |
#  |  request(self, resource, params=None, files=None, method_override=None)
#  |      Request a Twitter REST API or Streaming API resource.
#  |
#  |      :param resource: A valid Twitter endpoint (ex. "search/tweets")
#  |      :param params: Dictionary with endpoint parameters or None (default)
#  |      :param files: Dictionary with multipart-encoded file or None (default)
#  |      :param method_override: Request method to override or None (default)
#  |
#  |      :returns: TwitterResponse
#  |      :raises: TwitterConnectionError
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# What can we do with this twitter object?
# builtin method `dir` tells us...
dir(twitter)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_endpoint',
#  '_prepare_url',
#  'auth',
#  'proxies',
#  'request']

# %%
twitter.auth

# %%
# Get help on the `request` method using the builtin method called...`help`
help(twitter.request)
# Out:
# Help on method request in module TwitterAPI.TwitterAPI:
#
# request(resource, params=None, files=None, method_override=None) method of TwitterAPI.TwitterAPI.TwitterAPI instance
#     Request a Twitter REST API or Streaming API resource.
#
#     :param resource: A valid Twitter endpoint (ex. "search/tweets")
#     :param params: Dictionary with endpoint parameters or None (default)
#     :param files: Dictionary with multipart-encoded file or None (default)
#     :param method_override: Request method to override or None (default)
#
#     :returns: TwitterResponse
#     :raises: TwitterConnectionError

# %%
# Let's start by querying the search API
response = twitter.request('search/tweets', {'q': 'big+data'})

# %%
# What object is returned?
# builtin type method will tell us.
print(type(response))
dir(response)
# Out:
# <class 'TwitterAPI.TwitterAPI.TwitterResponse'>
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'close',
#  'get_iterator',
#  'get_quota',
#  'headers',
#  'json',
#  'response',
#  'status_code',
#  'stream',
#  'text']

# %%
response.json
# Out:
# <bound method TwitterResponse.json of <TwitterAPI.TwitterAPI.TwitterResponse object at 0x0000026B58BEEEB8>>

# %%
response.status_code
# See https://dev.twitter.com/overview/api/response-codes
# Out:
# 200

# %%
tweets = [r for r in response]

# %%
print('found %d tweets' % len(tweets))
# Out:
# found 15 tweets

# %%
type(tweets)
# Out:
# list

# %%
type(tweets[0])
# Out:
# dict

# %%
tweets[0]
# Out:
# {'created_at': 'Sat Dec 01 20:46:07 +0000 2018',
#  'id': 1068969513809559552,
#  'id_str': '1068969513809559552',
#  'text': 'RT @jmalvpal: El Big Data y la Inteligencia Artificial transforman el mundo de la música: IBM Watson BEAT. @ThinkBig_open https://t.co/1yQy…',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'jmalvpal',
#     'name': 'JM Alvarez-Pallete',
#     'id': 185166944,
#     'id_str': '185166944',
#     'indices': [3, 12]},
#    {'screen_name': 'ThinkBig_open',
#     'name': 'Think Big',
#     'id': 518388197,
#     'id_str': '518388197',
#     'indices': [107, 121]}],
#   'urls': []},
#  'metadata': {'result_type': 'recent', 'iso_language_code': 'ca'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 250327301,
#   'id_str': '250327301',
#   'name': 'Mercedes Botella',
#   'screen_name': 'MerBotella',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 222,
#   'friends_count': 504,
#   'listed_count': 6,
#   'created_at': 'Thu Feb 10 21:47:32 +0000 2011',
#   'favourites_count': 2810,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 2527,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/783037806973165568/wS2c4jcb_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/783037806973165568/wS2c4jcb_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/250327301/1417501201',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Sat Dec 01 20:45:06 +0000 2018',
#   'id': 1068969258300903424,
#   'id_str': '1068969258300903424',
#   'text': 'El Big Data y la Inteligencia Artificial transforman el mundo de la música: IBM Watson BEAT. @ThinkBig_open https://t.co/1yQydytIED',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ThinkBig_open',
#      'name': 'Think Big',
#      'id': 518388197,
#      'id_str': '518388197',
#      'indices': [93, 107]}],
#    'urls': [{'url': 'https://t.co/1yQydytIED',
#      'expanded_url': 'http://ow.ly/Ogzt30mPlUY',
#      'display_url': 'ow.ly/Ogzt30mPlUY',
#      'indices': [108, 131]}]},
#   'metadata': {'result_type': 'recent', 'iso_language_code': 'ca'},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 185166944,
#    'id_str': '185166944',
#    'name': 'JM Alvarez-Pallete',
#    'screen_name': 'jmalvpal',
#    'location': 'Europa',
#    'description': 'CEO Telefonica. Wayra Founder & Architect. Telecom, Technology, Economy, Innovation, Proniño, Think Big, Talentum, Open Future. Marathon runner.',
#    'url': 'http://t.co/f9NZ8yxADG',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/f9NZ8yxADG',
#        'expanded_url': 'http://www.telefonica.com',
#        'display_url': 'telefonica.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 73431,
#    'friends_count': 1008,
#    'listed_count': 1674,
#    'created_at': 'Tue Aug 31 11:25:55 +0000 2010',
#    'favourites_count': 1091,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 35190,
#    'lang': 'es',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2524802861/x17f771fsiv7jpbvc0yk_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2524802861/x17f771fsiv7jpbvc0yk_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/185166944/1429978976',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'ca'},
#  'is_quote_status': False,
#  'retweet_count': 2,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'ca'}

# %%
help(tweets[0])
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  get(self, key, default=None, /)
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(self, key, default=None, /)
#  |      Insert key with a value of default if key is not in the dictionary.
#  |
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Create a new dictionary with keys from iterable and values set to value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
tweets[0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
tweets[0]['text']
# Out:
# 'RT @jmalvpal: El Big Data y la Inteligencia Artificial transforman el mundo de la música: IBM Watson BEAT. @ThinkBig_open https://t.co/1yQy…'

# %%
tweets[0]['created_at']
# Out:
# 'Sat Dec 01 20:46:07 +0000 2018'

# %%
tweets[0]['text']
# Out:
# 'RT @jmalvpal: El Big Data y la Inteligencia Artificial transforman el mundo de la música: IBM Watson BEAT. @ThinkBig_open https://t.co/1yQy…'

# %%
tweets[0]['user']
# Out:
# {'id': 250327301,
#  'id_str': '250327301',
#  'name': 'Mercedes Botella',
#  'screen_name': 'MerBotella',
#  'location': '',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 222,
#  'friends_count': 504,
#  'listed_count': 6,
#  'created_at': 'Thu Feb 10 21:47:32 +0000 2011',
#  'favourites_count': 2810,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 2527,
#  'lang': 'en',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/783037806973165568/wS2c4jcb_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/783037806973165568/wS2c4jcb_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/250327301/1417501201',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
user = tweets[0]['user']
print('screen_name=%s, name=%s, location=%s' % (user['screen_name'], user['name'], user['location']))
# Out:
# screen_name=MerBotella, name=Mercedes Botella, location=

# %%
# Who follows this person?
# https://dev.twitter.com/docs/api/1.1/get/followers/list
screen_name = user['screen_name']
response  = twitter.request('followers/list', {'screen_name': screen_name, 'count':200})
followers = [follower for follower in response]
        
print('found %d followers for %s' % (len(followers), screen_name))
# See more about paging here: https://dev.twitter.com/docs/working-with-timelines
# Out:
# found 200 followers for MerBotella

# %%
print (followers[0]['screen_name'])
# Out:
# ScottJKyle1

# %% [markdown]
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 Free  on Noxzema Shave Care http://t.co/GGf59ox3
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 Free  on select Nexcare First Aid prod... http://t.co/t8YA2DQI
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 50% off on all LOreal Hair Color http://t.co/nMzC7d6z
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 50% off on select Multivitamins One A ... http://t.co/aIzibzkO
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) 20% off select Shea Moisture Hair, Soap and Baby P... http://t.co/ubuasvo3
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Revlon: Color Burst, Lip Butters, Just Bitten Lip ... http://t.co/uoyvVMln
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) ZZZQUIL Nightime Sleep Aid $4.99 http://t.co/P8qWm278
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Zyrtec as low as $19.99 http://t.co/ETfbGdpl
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 50% off on Nature's Bounty and Sundown... http://t.co/f9gBwgXE
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 50% off on select D59Walgreens Pain Re... http://t.co/Lh1RhOG5
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 50% off on Almay Cosmetics and Makeup ... http://t.co/EyJduCs3
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 Free 5 on Walgreens Omeprazole or Lans... http://t.co/BPcHjWyw
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 50% off on select Walgreens Childrens ... http://t.co/Vx1gzWHw
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Pampers Jumbo Pack Diapers $9.99 http://t.co/yW7RmMBV
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Acid Reducer Sale - Save on Prilosec, Zegrid and P... http://t.co/1CHlXmHH
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 50% off on select Walgreens Dental Care http://t.co/qmjssxeO
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Buy 1 Get 1 50% off on select Boost Nutritional Sh... http://t.co/S9tnIbW8
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) $39.99 Walgreens Stop Smoking Sale http://t.co/pN56P2QV
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) Infant Formula $23.99 http://t.co/yV87rxk6
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) 40% off all Twinlab Vitamins and Supplements - inc... http://t.co/3lT6Edb5
#
# New #coupon for WalgreensDealsS: (8/19 - 8/25) First Aid Sale - Buy 1 Get 1 50% off on select Ban... http://t.co/QUbaUGAz

# %% [markdown]
# # Find  the deals in the walgreensdealss tweets  that match products in SmartPortables MySQL product table

# %%
import re
import pymysql

cnx = pymysql.connect(user='root', password='root',
                              host='127.0.0.1',
                              database='knnhealthcare')
cursor = cnx.cursor()

query = ("SELECT productName FROM medicine_details")
cursor.execute(query)


dealMatchGauranteed=[]
for product in cursor:
    for tweet in timeline:
        deal = (tweet['text']).encode('ascii','ignore')
        if (len(re.findall(r'\s'+product[0]+'\s',deal.decode('utf-8'))) >= 1):
            dealMatchGauranteed = dealMatchGauranteed + [deal.decode('utf-8')]

# %%
# Sanity Test that  we got some deals
dealMatchGauranteed[:5]
# Out:
# ['New #coupon for WalgreensDealsS: (9/9 - 9/15) $4 off Centrum Multivitamins and Caltrate Calcium S... http://t.co/wICsELYi',
#  'New #coupon for WalgreensDealsS: (9/9 - 9/15) Miralax $19.99 http://t.co/MhkxhD29',
#  'New #coupon for WalgreensDealsS: (9/9 - 9/15) Allergy Relief on Claritin, Allegra, and Zyrtec as ... http://t.co/7VxBH88k',
#  'New #coupon for WalgreensDealsS: (8/19 - 8/25) Zyrtec as low as $19.99 http://t.co/ETfbGdpl']

# %% [markdown]
# # Create and write the deals into DealMatches.txt file that will be used by web-app of KNNHealthCare to display two deal matches

# %%
dealMatchFile = open('C:/apache-tomcat-7.0.34/webapps/KNNHealthCare/DealMatches.txt', 'w')

for deal in dealMatchGauranteed:
  dealMatchFile.write("%s\n" % deal)

dealMatchFile.close()
